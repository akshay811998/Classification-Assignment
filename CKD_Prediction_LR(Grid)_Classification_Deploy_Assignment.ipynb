# %%
import pickle

# %%
loaded_scaler = pickle.load(open("scaler.sav","rb"))
loaded_model=pickle.load(open("finalized_model_logisticregression.sav","rb"))
age = float(input("Enter age: "))
bp = float(input("Enter blood pressure: "))
al = float(input("Enter albumin: "))
su = float(input("Enter sugar: "))
bgr = float(input("Enter blood glucose random: "))
bu = float(input("Enter blood urea: "))
sc = float(input("Enter serum creatinine: "))
sod = float(input("Enter sodium: "))
pot = float(input("Enter potassium: "))
hrmo = float(input("Enter hemoglobin: "))
pcv = float(input("Enter packed cell volume: "))
wc = float(input("Enter white blood cell count: "))
rc = float(input("Enter red blood cell count: "))
sg_b = float(input("Is your specific gravity B class? (Yes = 1, No = 0)"))
sg_c = float(input("Is your specific gravity C class? (Yes = 1, No = 0)"))
sg_d = float(input("Is your specific gravity D class? (Yes = 1, No = 0)"))
sg_e = float(input("Is your specific gravity E class? (Yes = 1, No = 0)"))
rbc = int(input("Enter rbc (normal=1, abnormal=0): "))
pc = int(input("Enter pc (normal=1, abnormal=0): "))
pcc = int(input("Enter pcc (present=1, notpresent=0): "))
ba = int(input("Enter ba (present=1, notpresent=0): "))
htn = int(input("Enter hypertension (yes=1, no=0): "))
dm = int(input("Enter diabetes mellitus (yes=1, no=0): "))
cad = int(input("Enter coronary artery disease (yes=1, no=0): "))
appet = int(input("Enter appetite (good=1, poor=0): "))
pe = int(input("Enter pedal edema (yes=1, no=0): "))
ane = int(input("Enter anemia (yes=1, no=0): "))

result = loaded_model.predict(loaded_scaler.transform([[age, bp, al, su, bgr, bu, sc, sod, pot, hrmo, pcv, wc, rc, sg_b, sg_c, sg_d, sg_e, rbc, pc, pcc, ba, htn, dm, cad, appet, pe, ane]]))
print(result)
if result == 0:
    print("No Chronic Kidney Disease Predicted")
else:
    print ("Yes, You're affected with Chronic Kidney Disease")
# Out:
# Enter age:  12
# Enter blood pressure:  80
# Enter albumin:  0
# Enter sugar:  0
# Enter blood glucose random:  100
# Enter blood urea:  26
# Enter serum creatinine:  0.6
# Enter sodium:  137
# Enter potassium:  4.4
# Enter hemoglobin:  15.8
# Enter packed cell volume:  49
# Enter white blood cell count:  6600
# Enter red blood cell count:  5.4
# Is your specific gravity B class? (Yes = 1, No = 0) 0
# Is your specific gravity C class? (Yes = 1, No = 0) 0
# Is your specific gravity D class? (Yes = 1, No = 0) 0
# Is your specific gravity E class? (Yes = 1, No = 0) 0
# Enter rbc (normal=1, abnormal=0):  1
# Enter pc (normal=1, abnormal=0):  1
# Enter pcc (present=1, notpresent=0):  0
# Enter ba (present=1, notpresent=0):  0
# Enter hypertension (yes=1, no=0):  0
# Enter diabetes mellitus (yes=1, no=0):  0
# Enter coronary artery disease (yes=1, no=0):  0
# Enter appetite (good=1, poor=0):  1
# Enter pedal edema (yes=1, no=0):  0
# Enter anemia (yes=1, no=0):  0
# [0]
# ...
